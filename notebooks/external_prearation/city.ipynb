# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
original_df = pd.read_csv('../Data/Original/geoshape-city-geolod.csv', 
                          encoding='utf-8', 
                          dtype=str, 
                          index_col=False)

# %%
df = original_df.copy()

df[df['body']!=df['body_variants']]

df[df['suffix'].str.len()!=2]
# Out:
#       geolod_id    entry_id    body body_variants suffix prefname  \
# 4581     T8CebY  13100A1968    特別区部          特別区部  特別区部/      東京都
# 4670     cqgqp2  13B0010010    三宅島他          三宅島他      /      東京府
# 4672     i6uqhs  13B0010012     小笠原           小笠原    島庁/      東京府
# 4680     GKkUL7  13B0010020      八丈            八丈    島庁/      東京府
# 9064     g6U0K9  24B0140002  紀北町入会地        紀北町入会地      /      三重県
# 11566    tuqoql  32B0010001      隠岐       隠岐/隠岐島司    島庁/      島根県
# 12027    x8N6St  33B0040001   区界未確定         区界未確定      /      岡山県
# 16736    MWs4S6  47B0050001    沖大東島          沖大東島      /      沖縄県
# 16745    ewqggu  47B0050010    南大東島          南大東島      /      沖縄県
# 16746    h8uwcc  47B0050011    北大東島          北大東島      /      沖縄県
#
#       prefname_variants countyname countyname_variants   ne_class  hypernym  \
# 4581                東京都       特別区部                特別区部  市区町村/特別区部  東京都/特別区部
# 4670                東京府        NaN                 NaN     市区町村/他       東京府
# 4672                東京府        NaN                 NaN    市区町村/島庁       東京府
# 4680                東京府        NaN                 NaN    市区町村/島庁       東京府
# 9064                三重県       北牟婁郡                北牟婁郡     市区町村/他  三重県/北牟婁郡
# 11566               島根県        NaN                 NaN    市区町村/島庁       島根県
# 12027               岡山県        岡山市                 岡山市     市区町村/他   岡山県/岡山市
# 16736               沖縄県        島尻郡                 島尻郡     市区町村/他   沖縄県/島尻郡
# 16745               沖縄県        島尻郡                 島尻郡     市区町村/他   沖縄県/島尻郡
# 16746               沖縄県        島尻郡                 島尻郡     市区町村/他   沖縄県/島尻郡
#
#           latitude     longitude        address   code  valid_from  \
# 4581   35.68956800  139.69171700        東京都特別区部  13100  1947-03-15
# 4670     34.085209    139.524380        東京府三宅島他  13381         NaN
# 4672   26.64146700  142.15876500       東京府小笠原島庁  13000  1886-11-04
# 4680     30.489119    140.299774        東京府八丈島庁  13402         NaN
# 9064     34.151042    136.363509  三重県北牟婁郡紀北町入会地  24543         NaN
# 11566    37.245739    131.894081        島根県隠岐島庁  32000         NaN
# 12027  34.56605400  134.10490100    岡山県岡山市区界未確定    NaN         NaN
# 16736    24.467265    131.187929     沖縄県島尻郡沖大東島  47000         NaN
# 16745  25.82890300  131.23187200     沖縄県島尻郡南大東島  47357         NaN
# 16746  25.94571200  131.29891700     沖縄県島尻郡北大東島  47358         NaN
#
#          valid_to                                        description  \
# 4581          NaN                1/東京都庁/東京都新宿区西新宿2-8-1/P28-13_13.xml
# 4670   1946-10-01         9/ポリゴンの重心/(19200101\13\13B0010010.wkt.txt)
# 4672   1926-01-01  2/母島支所/小笠原村母島字元地/P34-14_13.xml/(19200101\13\13...
# 4680          NaN         9/ポリゴンの重心/(19200101\13\13B0010020.wkt.txt)
# 9064          NaN    9/ポリゴンの重心に準ずる点/(20140401\24\24B0140002.wkt.txt)
# 11566         NaN         9/ポリゴンの重心/(19200101\32\32B0010001.wkt.txt)
# 12027         NaN  5/犬島コミュニティハウス/犬島326番地18/P05-10_33-g.xml/(20130...
# 16736  1946-06-12         9/ポリゴンの重心/(19200101\47\47B0050001.wkt.txt)
# 16745  1946-06-12  1/南大東村役場/南大東村字南144-1/P34-14_47.xml/(19200101\4...
# 16746  1946-06-12  1/北大東村役場/北大東村字中野218/P34-14_47.xml/(19200101\47...
#
#                                                   source
# 4581   https://geoshape.ex.nii.ac.jp/city/resource/13...
# 4670   https://geoshape.ex.nii.ac.jp/city/resource/13...
# 4672   https://geoshape.ex.nii.ac.jp/city/resource/13...
# 4680   https://geoshape.ex.nii.ac.jp/city/resource/13...
# 9064   https://geoshape.ex.nii.ac.jp/city/resource/24...
# 11566  https://geoshape.ex.nii.ac.jp/city/resource/32...
# 12027  https://geoshape.ex.nii.ac.jp/city/resource/33...
# 16736  https://geoshape.ex.nii.ac.jp/city/resource/47...
# 16745  https://geoshape.ex.nii.ac.jp/city/resource/47...
# 16746  https://geoshape.ex.nii.ac.jp/city/resource/47...
